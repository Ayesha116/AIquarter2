# %%
import pandas as pd

# %%
dic2 = {"names" : ["ayesha", "tara","aneeq","afifa","shabana","ariba"],
      "Aiforeveryone": [78,90,20,88,99,100],
      "Python1" : [90,78,65,43,98,100],
      "Python2": [66,70,98,76,65,75]}

# %%
dic2
# Out:
# {'names': ['ayesha', 'tara', 'aneeq', 'afifa', 'shabana', 'ariba'],
#  'Aiforeveryone': [78, 90, 20, 88, 99, 100],
#  'Python1': [90, 78, 65, 43, 98, 100],
#  'Python2': [66, 70, 98, 76, 65, 75]}

# %%
dframe = pd.DataFrame(dic2,index =[1,2,3,4,5,6])
dframe
# Out:
#      names  Aiforeveryone  Python1  Python2
# 1   ayesha             78       90       66
# 2     tara             90       78       70
# 3    aneeq             20       65       98
# 4    afifa             88       43       76
# 5  shabana             99       98       65
# 6    ariba            100      100       75

# %%
dframe["total"] = dframe["Aiforeveryone"] + dframe["Python1"] + dframe["Python2"] 
dframe
# Out:
#      names  Aiforeveryone  Python1  Python2  total
# 1   ayesha             78       90       66    234
# 2     tara             90       78       70    238
# 3    aneeq             20       65       98    183
# 4    afifa             88       43       76    207
# 5  shabana             99       98       65    262
# 6    ariba            100      100       75    275

# %%
import numpy as np

# %%
dframe["status"] = ["Pass" if marks>200 else "fail" for marks in dframe.total]
dframe
# Out:
#      names  Aiforeveryone  Python1  Python2  total status status1
# 1   ayesha             78       90       66    234   Pass    pass
# 2     tara             90       78       70    238   Pass    pass
# 3    aneeq             20       65       98    183   fail    pass
# 4    afifa             88       43       76    207   Pass    pass
# 5  shabana             99       98       65    262   Pass    pass
# 6    ariba            100      100       75    275   Pass    pass

# %%
dframe["status1"] = np.where(((dframe["Aiforeveryone"]<70) & (dframe["Python1"]<50) & (dframe["Python2"]<50)),"fail","pass")
dframe
# Out:
#      names  Aiforeveryone  Python1  Python2  total status status1
# 1   ayesha             78       90       66    234   Pass    pass
# 2     tara             90       78       70    238   Pass    pass
# 3    aneeq             20       65       98    183   fail    pass
# 4    afifa             88       43       76    207   Pass    pass
# 5  shabana             99       98       65    262   Pass    pass
# 6    ariba            100      100       75    275   Pass    pass

# %%
frame = pd.DataFrame(dic2,columns=[ "Python1", "Python2","Aiforeveryone","total"],index = ["one","two","three","four","five","six"])
frame
# Out:
#        Python1  Python2  Aiforeveryone total
# one         90       66             78   NaN
# two         78       70             90   NaN
# three       65       98             20   NaN
# four        43       76             88   NaN
# five        98       65             99   NaN
# six        100       75            100   NaN

# %%
frame.columns
# Out:
# Index(['Python1', 'Python2', 'Aiforeveryone', 'total'], dtype='object')

# %%
frame.index
# Out:
# Index(['one', 'two', 'three', 'four', 'five', 'six'], dtype='object')

# %%
value = pd.Series([200,100,299],index = ["two", "four","three"])

# %%
frame.total = value

# %%
frame
# Out:
#        Python1  Python2  Aiforeveryone  total
# one         90       66             78    NaN
# two         78       70             90  200.0
# three       65       98             20  299.0
# four        43       76             88  100.0
# five        98       65             99    NaN
# six        100       75            100    NaN

# %%
newdic = {"Texas": {2001:2.4, 2002:3},
         "ohio" : {2000:1.5 , 2001:2,2002:4}}

# %%
frame1 = pd.DataFrame(newdic)
frame1
# Out:
#       Texas  ohio
# 2000    NaN   1.5
# 2001    2.4   2.0
# 2002    3.0   4.0

# %%
pd.DataFrame(frame1,index = [2001,2002,2003])
# Out:
#       Texas  ohio
# 2001    2.4   2.0
# 2002    3.0   4.0
# 2003    NaN   NaN

# %%
#dictionary from frame
dic1 = {"Texas":frame1["ohio"][:-1],
       "ohio":frame1["Texas"][:2]}
dic1
# Out:
# {'Texas': 2000    1.5
#  2001    2.0
#  Name: ohio, dtype: float64, 'ohio': 2000    NaN
#  2001    2.4
#  Name: Texas, dtype: float64}

# %%
frame2 = pd.DataFrame(dic1)
frame2
# Out:
#       Texas  ohio
# 2000    1.5   NaN
# 2001    2.0   2.4

# %%
frame2.index.name="year"; frame2.columns.name = "states"

# %%
frame2
# Out:
# states  Texas  ohio
# year
# 2000      1.5   NaN
# 2001      2.0   2.4

# %%
frame2.values
# Out:
# array([[1.5, nan],
#        [2. , 2.4]])

# %% [markdown]
#                        Essential Functionality

# %%
#reindexing
obj = pd.Series([2,4,6,8,10], index = ["a","b","c","d","e"])
obj.reindex(range(9))
obj
# Out:
# a     2
# b     4
# c     6
# d     8
# e    10
# dtype: int64

# %%
obj3 = pd.Series(['blue', 'purple', 'yellow'], index=[0,2,4])
obj3.reindex(range(6))
# Out:
# 0      blue
# 1       NaN
# 2    purple
# 3       NaN
# 4    yellow
# 5       NaN
# dtype: object

# %%
obj3.reindex(range(6),method="ffill")
# Out:
# 0      blue
# 1      blue
# 2    purple
# 3    purple
# 4    yellow
# 5    yellow
# dtype: object

# %%
obj

# %% [markdown]
#             reindexing on data frame

# %%
dataframe = pd.DataFrame(np.arange(9).reshape(3,3),index = ["a","b","c"], columns=["ohio", "Texas","California"])
dataframe
# Out:
#    ohio  Texas  California
# a     0      1           2
# b     3      4           5
# c     6      7           8

# %%
frame3 = dataframe.reindex(["a","b","c","d"])
frame3
# Out:
#    ohio  Texas  California
# a   0.0    1.0         2.0
# b   3.0    4.0         5.0
# c   6.0    7.0         8.0
# d   NaN    NaN         NaN

# %%
states = ["California","Texas", "Newyork"]
frame3.reindex(columns = states)
# Out:
#    California  Texas  Newyork
# a         2.0    1.0      NaN
# b         5.0    4.0      NaN
# c         8.0    7.0      NaN
# d         NaN    NaN      NaN

# %%
frame3.reindex(index = ["a", "c","f","e","b","d"], columns=["Texas", "utah","Newyork","California","Ohio"])
# Out:
#    Texas  utah  Newyork  California  Ohio
# a    1.0   NaN      NaN         2.0   NaN
# c    7.0   NaN      NaN         8.0   NaN
# f    NaN   NaN      NaN         NaN   NaN
# e    NaN   NaN      NaN         NaN   NaN
# b    4.0   NaN      NaN         5.0   NaN
# d    NaN   NaN      NaN         NaN   NaN

# %%
newframe = pd.DataFrame(np.arange(1,101).reshape((20,5)), columns = ["a","b","c","d", "e"],index=range(1,101,5))
newframe
# Out:
#      a   b   c   d    e
# 1    1   2   3   4    5
# 6    6   7   8   9   10
# 11  11  12  13  14   15
# 16  16  17  18  19   20
# 21  21  22  23  24   25
# 26  26  27  28  29   30
# 31  31  32  33  34   35
# 36  36  37  38  39   40
# 41  41  42  43  44   45
# 46  46  47  48  49   50
# 51  51  52  53  54   55
# 56  56  57  58  59   60
# 61  61  62  63  64   65
# 66  66  67  68  69   70
# 71  71  72  73  74   75
# 76  76  77  78  79   80
# 81  81  82  83  84   85
# 86  86  87  88  89   90
# 91  91  92  93  94   95
# 96  96  97  98  99  100

# %%
newframe1 = pd.DataFrame(np.arange(1,101).reshape((20,5)), columns = list("abcde"),index=range(1,101,5))
newframe1
# Out:
#      a   b   c   d    e
# 1    1   2   3   4    5
# 6    6   7   8   9   10
# 11  11  12  13  14   15
# 16  16  17  18  19   20
# 21  21  22  23  24   25
# 26  26  27  28  29   30
# 31  31  32  33  34   35
# 36  36  37  38  39   40
# 41  41  42  43  44   45
# 46  46  47  48  49   50
# 51  51  52  53  54   55
# 56  56  57  58  59   60
# 61  61  62  63  64   65
# 66  66  67  68  69   70
# 71  71  72  73  74   75
# 76  76  77  78  79   80
# 81  81  82  83  84   85
# 86  86  87  88  89   90
# 91  91  92  93  94   95
# 96  96  97  98  99  100

# %%
#getting values from dataframe
newframe1.loc[96]["c"]
# Out:
# 98

# %%
frame3
# Out:
#    ohio  Texas  California
# a   0.0    1.0         2.0
# b   3.0    4.0         5.0
# c   6.0    7.0         8.0
# d   NaN    NaN         NaN

# %%
frame3.loc[::-1]
# Out:
#    ohio  Texas  California
# d   NaN    NaN         NaN
# c   6.0    7.0         8.0
# b   3.0    4.0         5.0
# a   0.0    1.0         2.0

# %%
frame3.loc[::-1][1::]
# Out:
#    ohio  Texas  California
# c   6.0    7.0         8.0
# b   3.0    4.0         5.0
# a   0.0    1.0         2.0

# %%
frame3.iloc[1:3]
# Out:
#    ohio  Texas  California
# b   3.0    4.0         5.0
# c   6.0    7.0         8.0

# %%
frame3.loc["a"]["California"]
# Out:
# 2.0

# %%
frame3.loc["b"]["Ohio"] = 9

# %%
frame3
# Out:
#    ohio  Texas  California
# a   0.0    1.0         2.0
# b   4.0    3.0         5.0
# c   6.0    7.0         8.0
# d   0.0    0.0         0.0

# %%
#swaping of values
frame3.loc["b"][[0,1]] = frame3.loc["b"][[1,0]] 
frame3
# Out:
#    ohio  Texas  California
# a   0.0    1.0         2.0
# b   4.0    3.0         5.0
# c   6.0    7.0         8.0
# d   0.0    0.0         0.0

# %%
frame3
# Out:
#    ohio  Texas  California
# a   0.0    1.0         2.0
# b   4.0    3.0         5.0
# c   6.0    7.0         8.0
# d   0.0    0.0         0.0

# %%
#fillno method
frame3.fillna(0)
# Out:
#    ohio  Texas  California
# a   0.0    1.0         2.0
# b   4.0    3.0         5.0
# c   6.0    7.0         8.0
# d   0.0    0.0         0.0

# %%
frame3
# Out:
#    ohio  Texas  California
# a   0.0    1.0         2.0
# b   4.0    3.0         5.0
# c   6.0    7.0         8.0
# d   0.0    0.0         0.0

# %%
frame3.fillna(2)  #inplace command made change in memory in original data
frame3
# Out:
#    ohio  Texas  California
# a   0.0    1.0         2.0
# b   4.0    3.0         5.0
# c   6.0    7.0         8.0
# d   0.0    0.0         0.0

# %%
df = pd.read_csv("stddata.csv")
df
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 0    022-14-19987  BS(CS)                     Abdul Basit   28     8.0
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17     NaN
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 3    022-14-19718  BS(CS)                  Ahmed Ali Raza   14     7.0
# 4   022-14-110648  BS(CS)                 Ahsan Ali Vohra   27     7.0
# 5   022-14-110232  BS(CS)                     Ameer Hamza   25     9.0
# 6   022-14-110588  BS(CS)                   Anas Ali Khan   28     5.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26     9.0
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19     9.0
# 9   022-14-110599  BS(CS)                         Arsalan   28     8.0
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi   30     8.0
# 11  022-14-110591  BS(CS)                     Habib Ullah   28     8.0
# ...

# %%
df.head()
# Out:
#     Student Code  Degree     Student Name  Mid  Quiz 1  Quiz 2  \
# 0   022-14-19987  BS(CS)      Abdul Basit   28     8.0     3.0
# 1  022-14-110233  BS(CS)      Adeel Ahmed   17     NaN     5.0
# 2  022-14-110585  BS(CS)     Afrah Zareen   18     5.0     2.0
# 3   022-14-19718  BS(CS)   Ahmed Ali Raza   14     7.0     2.0
# 4  022-14-110648  BS(CS)  Ahsan Ali Vohra   27     7.0     6.0
#
#    Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 0                8           7.0           9.0                    9
# 1                5           8.0          10.0                   10
# 2                5           8.0          10.0                   10
# 3                7           NaN           2.0                    2
# 4                7           7.0           9.0                    9
#
#    Total Sessional (50)  Final (50)  Total (100) Grade
# 0                    45        25.0           70     B
# 1                    32        18.0           50     F
# ...

# %%
student = pd.DataFrame(df["Best of Quizzes"]>7)
students
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6     False
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12    False
# 13     True
# 14    False
# 15    False
# 16    False
# 17     True
# 18    False
# 19     True
# 20    False
# 21     True
# 22    False
# 23    False
# 24    False
# 25     True
# 26    False
# 27     True
# 28    False
# 29    False
# 30     True
# 31    False
# 32    False
# 33    False
# 34     True
# 35     True
# 36     True
# 37     True
# 38    False
# 39    False
# 40     True
# 41    False
# 42    False
# 43     True
# 44    False
# 45     True
# 46     True
# 47     True
# Name: Best of Quizzes, dtype: bool

# %%
(df[df["Best of Quizzes"]>7]) & (df[df["Assignment 1"]>7])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1788         try:
# -> 1789             result = op(x, y)
#    1790         except TypeError:
#
# TypeError: unsupported operand type(s) for &: 'str' and 'bool'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-149-c43d1e640291> in <module>
# ----> 1 (df[df["Best of Quizzes"]>7]) & (df[df["Assignment 1"]>7])
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in f(self, other, axis, level, fill_value)
#    2021             # Another DataFrame
#    2022             pass_op = op if should_series_dispatch(self, other, op) else na_op
# -> 2023             return self._combine_frame(other, pass_op, fill_value, level)
# ...
